# %% [markdown]
# <a href="https://colab.research.google.com/github/chamlagaig/ComputerVision/blob/main/Project_Stage_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project Stage 2 - Team Visionaries
# ##Team members: Cade Mack, Amanda Cheng, Hari Chamlagai, Anjolaoluwa Daodu, Aryani Patel, Haroon Kaid
# To find data for our project, we needed any sort of film or frames of a hockey game. For this, we found a film of a match between the Burnaby Bulldogs and the Coquitlam Chiefs. This is an H2 minor game which is good for our data because the puck will likely move at lower speeds which may help because more frames will have clear images of the puck for recognition.
#
# https://www.youtube.com/watch?v=TBhpx1eNMsA
#
# We took a short clip of this game and then tore apart the frames and after that we had 358 frames of hockey footage to work with. Unfortunately, not all of these frames have the puck clearly in view whether it be occluded by a player, the wall, or a hockey stick. However, this is a problem that will always be true for this solution, so it doesn't hurt to have this in our data.
#
# The link to the Google Drive folder holding the images is here:
# https://drive.google.com/drive/folders/17NeMSizaDLWzJqaG6pzxAeNq0DS5zlGr?usp=sharing

# %%
import os
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
cd MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Below this is the code that generated all of the images for our data. Of course, it will only work if the appropriate mp4 is saved locally in your drive. However the photos are already created, so this code probably shouldnt be run again.

# %%
# # Importing all necessary libraries 
# import cv2 
# import os 

# # Read the video from specified path 
# cam = cv2.VideoCapture("hockeyfilm.mp4") 

# try: 

#     # creating a folder named data 
#     if not os.path.exists('hockeyPics'): 
#         os.makedirs('hockeyPics') 

# # if not created then raise error 
# except OSError: 
#     print ('Error: Creating directory of data') 

# # frame 
# currentframe = 0

# skipframes = 5

# while(True): 

#     # reading from frame 
#     ret,frame = cam.read() 

#     for i in range(skipframes):
#       cam.read()

#     if ret: 
#         # if video is still left continue creating images 
#         name = './hockeyPics/frame' + str(currentframe) + '.jpg'
#         print ('Creating...' + name) 

#         # writing the extracted images 
#         cv2.imwrite(name, frame) 

#         # increasing counter so that it will 
#         # show how many frames are created 
#         currentframe += 1
#     else: 
#         break

# # Release all space and windows once done 
# cam.release() 
# cv2.destroyAllWindows()

# %%
# Globbing all the pictures together
import glob
images = glob.glob(f'hockeyPics/*.jpg')

# %%
# Just displaying a random image from the dataset
i = randint(len(images)-1)
img = imread(images[i])

imshow(img)

# %%
print("Dimensions of image: " + str(img.shape))
print("Amount of Images: " + str(len(images)))
# Out:
# Dimensions of image: (720, 1280, 3)
# Amount of Images: 358

# %% [markdown]
# Unfortunately, due to the nature of how we got this data and the nature of the problem, this data is not labelled. We may be able to label this data in the future if necessary, but we currently do not believe that will be necessary if we can utilize knowledge-based techniques for our solution.
